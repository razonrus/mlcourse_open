# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению. Сессия № 3
# <center> Автор материала: Павел Нестеров (@mephistopheies).
#
# Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center> Домашняя работа №4
# ## <center> Логистическая регрессия в задаче тегирования вопросов StackOverflow
#
# **Надо вывести формулы, где это просится (да, ручка и бумажка), заполнить код в клетках и выбрать ответы в [веб-форме](https://docs.google.com/forms/d/100c3Ek94UL-VRwXrN4lxCSnGjfJrl6Gc96G21DNCh4w).**
#
# ## 0. Описание задачи
#
# В этой домашней работе мы с вами изучим и запрограммируем модель для прогнозирования тегов по тексту вопроса на базе многоклассовой логистической регрессии. В отличие от обычной постановки задачи классификации (multiclass), в данном случае один пример может принадлежать одновременно к нескольким классам (multilabel). Мы будем реализовывать онлайн-версию алгоритма multilabel-классификации.
#
# Мы будем использовать небольшую выборку из протеггированных вопросов с сайта StackOverflow размером в 125 тысяч примеров (около 150 Мб, скачайте по [этой](https://drive.google.com/open?id=0B4bl7YMqDnViYVo0V2FubFVhMFE) ссылке).
#
# PS: Можно показать, что такая реализация совсем не эффективная и проще было бы использовать векторизированные вычисления. Для данного датасета так и есть. Но на самом деле подобные реализации используются в жизни, но естественно, написаны они не на Python. Например, в онлайн-моделях прогнозирования [CTR](https://en.wikipedia.org/wiki/Click-through_rate) юзеру показывается баннер, затем в зависимости от наличия клика происходит обновление параметров модели. В реальной жизни параметров модели может быть несколько сотен миллионов, а у юзера из этих ста миллионов от силы сто или тысяча параметров отличны от нуля, векторизировать такие вычисления не очень эффективно. Обычно все это хранится в огромных кластерах в in-memory базах данных, а обработка пользователей происходит распределенно.
#
# PS2:
# - в процессе решения домашней работы вам придется работать с текстом, и у вас может возникнуть желание сделать очевидный препроцессинг, например привести все слова в нижний регистр, в-общем **этого делать не нужно, если не оговорено заранее в задании**

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.19.6-py2.py3-none-any.whl (52kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.19.6

# %%
# !pip install watermark
# %load_ext watermark
# Out:
# Collecting watermark
#   Downloading watermark-1.6.0-py3-none-any.whl
# Requirement already satisfied: ipython in c:\programdata\anaconda3\lib\site-packages (from watermark)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: jedi>=0.10 in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: simplegeneric>0.8 in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: prompt_toolkit<2.0.0,>=1.0.4 in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython->watermark)
# Requirement already satisfied: ipython_genutils in c:\programdata\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->watermark)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->watermark)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt_toolkit<2.0.0,>=1.0.4->ipython->watermark)
# Installing collected packages: watermark
# Successfully installed watermark-1.6.0

# %% [markdown]
# Выведем версии используемых библиотек. Совпадут ли ответы в случае других версий - не гарантируется.

# %%
# %watermark -v -m -p numpy,scipy,pandas,matplotlib,sklearn -g
# Out:
# CPython 3.6.1
# IPython 5.3.0
#
# numpy 1.14.0
# scipy 1.0.0
# pandas 0.22.0
# matplotlib 2.1.2
# sklearn 0.19.1
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)
# system     : Darwin
# release    : 17.4.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit
# Git hash   : 45c8c34462bbf54d2a05de99fb9f0a6491fa1e27

# %%
# %watermark -v -m -p numpy,scipy,pandas,matplotlib,sklearn -g
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8ede756c42f4> in <module>()
# ----> 1 get_ipython().magic('watermark -v -m -p numpy,scipy,pandas,matplotlib,sklearn -g')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# <decorator-gen-126> in watermark(self, line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\watermark\watermark.py in watermark(self, line)
#     127                 self.out += '\nhost name%s: %s' % (space, gethostname())
#     128             if args.githash:
# --> 129                 self._get_commit_hash(bool(args.machine))
#     130             if args.gitrepo:
#     131                 self._get_git_remote_origin(bool(args.machine))
#
# C:\ProgramData\Anaconda3\lib\site-packages\watermark\watermark.py in _get_commit_hash(self, machine)
#     194         process = subprocess.Popen(['git', 'rev-parse', 'HEAD'],
#     195                                    shell=False,
# --> 196                                    stdout=subprocess.PIPE)
#     197         git_head_hash = process.communicate()[0].strip()
#     198         space = ''
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#     995                                          env,
#     996                                          os.fspath(cwd) if cwd is not None else None,
# --> 997                                          startupinfo)
#     998             finally:
#     999                 # Child is launched. Close the parent's copy of those pipe
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")
plt.rcParams['figure.figsize'] = 16, 12
from tqdm import tqdm_notebook
import pandas as pd
from collections import defaultdict

# поменяйте на свой путь
DS_FILE_NAME = 'C:/Users/AgileDeveloper/data.hw4/stackoverflow_sample_125k.tsv'
DS_FILE_NAME56 = 'C:/Users/AgileDeveloper/data.hw4/stackoverflow_sample_56.tsv'
TAGS_FILE_NAME = 'C:/Users/AgileDeveloper/data.hw4/top10_tags.tsv'

# %%
top_tags = []
with open(TAGS_FILE_NAME, 'r') as f:
    for line in f:
        top_tags.append(line.strip())
top_tags = set(top_tags)
print(top_tags)
# Out:
# {'c++', 'php', 'java', 'html', 'c#', 'jquery', 'python', 'android', 'ios', 'javascript'}

# %% [markdown]
# ## 1. Многоклассовая логистическая регрессия
#
# Вспомним, как получается логистическая регрессия для двух классов $\left\{0, 1\right\}$, вероятность принадлежности объекта к классу $1$ выписывается по теореме Байеса:
#
# $$\large \begin{array}{rcl}
# p\left(c = 1 \mid \textbf{x}\right) &=& \dfrac{p\left(\textbf{x} \mid c = 1\right)p\left(c = 1\right)}{p\left(\textbf{x} \mid c = 1\right)p\left(c = 1\right) + p\left(\textbf{x} \mid c = 0\right)p\left(c = 0\right)} \\
# &=& \dfrac{1}{1 + e^{-a}} = \sigma\left(a\right)
# \end{array}$$
# где:
# - $\textbf{x}$ – вектор признаков объекта
# - $\sigma$ – обозначение функции логистического сигмоида при скалярном аргументе
# - $a = \log \frac{p\left(\textbf{x} \mid c = 1\right)p\left(c = 1\right)}{p\left(\textbf{x} \mid c = 0\right)p\left(c = 0\right)} = \sum_{i=0}^M w_i x_i$ – это отношение мы моделируем линейной функцией от признаков объекта и параметров модели
#
# Данное выражение легко обобщить до множества из $K$ классов, изменится только знаменатель в формуле Байеса. Запишем вероятность принадлежности объекта к классу $k$:
# $$\large \begin{array}{rcl}
# p\left(c = k \mid \textbf{x}\right) &=& \dfrac{p\left(\textbf{x} \mid c = k\right)p\left(c = k\right)}{\sum_{i=1}^K p\left(\textbf{x} \mid c = i\right)p\left(c = i\right)} \\
# &=& \dfrac{e^{z_k}}{\sum_{i=1}^{K}e^{z_i}} = \sigma_k\left(\textbf{z}\right)
# \end{array}$$
# где:
# - $\sigma_k$ – обозначение функции softmax при векторном аргументе
# - $z_k = \log p\left(\textbf{x} \mid c = k\right)p\left(c = k\right) = \sum_{i=0}^M w_{ki} x_i$ – это выражение моделируется линейной функцией от признаков объекта и параметров модели для класса $k$

# %% [markdown]
# Для моделирования полного правдоподобия примера мы используем [категориальное распределение](https://en.wikipedia.org/wiki/Categorical_distribution), а лучше его логарифм (для удобства):
#
# $$\large \begin{array}{rcl}
# \mathcal{L} = \log p\left({\textbf{x}, y}\right) &=& \log \prod_{i=1}^K \sigma_i\left(\textbf{z}\right)^{y_i} \\
# &=& \sum_{i=1}^K y_i \log \sigma_i\left(\textbf{z}\right)
# \end{array}$$
#
# Получается хорошо знакомая нам функция [cross entropy](https://en.wikipedia.org/wiki/Cross_entropy) (если домножить на $-1$). Правдоподобие нужно максимизировать, а, соответственно, перекрестную энтропию нужно минимизировать. Продифференцировав по параметрам модели, мы _легко_ получим правила обновления весов для градиентного спуска, **проделайте этот вывод, если вы его не делали** (если вы вдруг сдались, то на [этом](https://www.youtube.com/watch?v=-WiR16raQf4) видео есть разбор вывода, понимание этого вам понадобится для дальнейшего выполнения задания; если предпочитаете текст, то и он есть [тут](https://www.ics.uci.edu/~pjsadows/notes.pdf) и [тут](https://eli.thegreenplace.net/2016/the-softmax-function-and-its-derivative/)):
#
# $$\large \begin{array}{rcl}
# \frac{\partial \mathcal{L}}{\partial w_{km}} &=& x_m \left(y_k - \sigma_k\left(\textbf{z}\right)\right)
# \end{array}$$
#
# В стандартной формулировке получается, что вектор $\left(\sigma_1, \sigma_2, \ldots, \sigma_K\right)$ образует дискретное вероятностное распределение, т.е. $\sum_{i=1}^K \sigma_i = 1$. Но в нашей постановке задачи каждый пример может иметь несколько тегов или одновременно принадлежать к нескольким классам. Для этого мы немного изменим модель:
# - будем считать, что все теги независимы друг от друга, т.е. каждый исход – это логистическая регрессия на два класса (либо есть тег, либо его нет), тогда вероятность наличия тега у примера запишется следующим образом (каждый тег/класс как и в многоклассовой логрегрессии имеет свой набор параметров):
# $$\large p\left(\text{tag}_k \mid \textbf{x}\right) = \sigma\left(z_k\right) = \sigma\left(\sum_{i=1}^M w_{ki} x^i \right)$$
# - наличие каждого тега мы будем моделировать с помощью <a href="https://en.wikipedia.org/wiki/Bernoulli_distribution">распределения Бернулли</a>
#
# <font color="red">Вопрос 1.</font> Ваше первое задание –  записать упрощенное выражение логарифма правдоподобия примера с признаками $\textbf{x}$. Как правило, многие алгоритмы оптимизации имеют интерфейс для минимизации функции, мы последуем этой же традиции и домножим полученное выражение на $-1$, а во второй части выведем формулы для минимизации полученного выражения.

# %% [markdown]
# <font color="red">Варианты ответа:</font>
# 1. $\large -\mathcal{L} = -\sum_{i=1}^M y_i \log \sigma\left(z_i\right) + \left(1 - y_i\right) \log \left(1 - \sigma\left(z_i\right)\right)$
# 2. $\large -\mathcal{L} = -\sum_{i=1}^K y_i \log \sigma\left(z_i\right) + \left(1 - y_i\right) \log \left(1 - \sigma\left(z_i\right)\right)$
# 3. $\large -\mathcal{L} = -\sum_{i=1}^K z_i \log \sigma\left(y_i\right) + \left(1 - z_i\right) \log \left(1 - \sigma\left(y_i\right)\right)$
# 4. $\large -\mathcal{L} = -\sum_{i=1}^M z_i \log \sigma\left(y_i\right) + \left(1 - z_i\right) \log \left(1 - \sigma\left(y_i\right)\right)$

# %% [markdown]
# ## 2. Вывод формулы обновления весов
#
# <font color="red">Вопрос 2.</font> В качестве второго задания вам предоставляется возможность вывести формулу градиента для $-\mathcal{L}$. Какой вид она будет иметь?

# %% [markdown]
# <font color="red">Варианты ответа:</font>:
# 1. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = -x_m \left(\sigma\left(z_k\right) - y_k\right)$
# 2. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = -x_m \left(y_k - \sigma\left(z_k\right)\right)$
# 3. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = \left(\sigma\left(z_k\right)x_m - y_k\right)$
# 4. $\large -\frac{\partial \mathcal{L}}{\partial w_{km}} = \left(y_k - \sigma\left(z_k\right)x_m\right)$

# %% [markdown]
# ## 3. Реализация базовой модели
#
# Вам предлагается каркас класса модели, разберите его внимательно, обращайте внимание на комментарии. Затем заполните пропуски, запустите полученную модель и ответьте на проверочный вопрос.
#
# Как вы могли уже заметить, при обновлении веса $w_{km}$ используется значение признака $x_m$, который равен $0$, если слова с индексом $m$ нет в предложении, и больше нуля, если такое слово есть. В нашем случае, чтобы не пересчитывать [bag-of-words](https://en.wikipedia.org/wiki/Bag-of-words_model) самим или с помощью [sklearn.feature_extraction.text.CountVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html#sklearn.feature_extraction.text.CountVectorizer), мы будем идти по словам предложения в порядке их следования. Если какое-то слово встречается несколько раз, то мы добавляем его в аккумулятор со своим весом. В итоге получится то же самое, как если сначала посчитать количество одинаковых слов и домножить на соответствующий вес. Соответственно, при вычислении линейной комбинации $z$ весов модели и признаков примера необходимо учитывать только ненулевые признаки объекта.
#
# Подсказка:
# - если реализовывать вычисление сигмоида так же, как в формуле, то при большом отрицательном значении $z$ вычисление $e^{-z}$ превратится в очень большое число, которое вылетит за допустимые пределы
# - в то же время $e^{-z}$ от большого положительного $z$ будет нулем
# - воспользуйтесь свойствами функции $\sigma$ для того, чтобы пофиксить эту ошибку и реализовать $\sigma$ без риска overflow.

# %%
tags=top_tags
_w = dict([(t, defaultdict(int)) for t in tags])

# %%
_w
# Out:
# {'android': defaultdict(int, {}),
#  'c#': defaultdict(int, {}),
#  'c++': defaultdict(int, {}),
#  'html': defaultdict(int, {}),
#  'ios': defaultdict(int, {}),
#  'java': defaultdict(int, {}),
#  'javascript': defaultdict(int, {}),
#  'jquery': defaultdict(int, {}),
#  'php': defaultdict(int, {}),
#  'python': defaultdict(int, {})}

# %%
_b = dict([(t, 0) for t in tags])

# %%
_vocab = {}

# %%
len(_vocab)
# Out:
# 0

# %%
_tags = set(tags)

# %%
line='i ve got some code in window scroll that checks if an element is visible then triggers another function however only the first section of code is firing both bits of code work in and of themselves if i swap their order whichever is on top fires correctly my code is as follows fn isonscreen function use strict var win window viewport top win scrolltop left win scrollleft bounds this offset viewport right viewport left + win width viewport bottom viewport top + win height bounds right bounds left + this outerwidth bounds bottom bounds top + this outerheight return viewport right lt bounds left viewport left gt bounds right viewport bottom lt bounds top viewport top gt bounds bottom window scroll function use strict var load_more_results ajax load_more_results isonscreen if load_more_results true loadmoreresults var load_more_staff ajax load_more_staff isonscreen if load_more_staff true loadmorestaff what am i doing wrong can you only fire one event from window scroll i assume not 	javascript jquery'
pair = line.strip().split('\t')

# %%
pair
# Out:
# ['i ve got some code in window scroll that checks if an element is visible then triggers another function however only the first section of code is firing both bits of code work in and of themselves if i swap their order whichever is on top fires correctly my code is as follows fn isonscreen function use strict var win window viewport top win scrolltop left win scrollleft bounds this offset viewport right viewport left + win width viewport bottom viewport top + win height bounds right bounds left + this outerwidth bounds bottom bounds top + this outerheight return viewport right lt bounds left viewport left gt bounds right viewport bottom lt bounds top viewport top gt bounds bottom window scroll function use strict var load_more_results ajax load_more_results isonscreen if load_more_results true loadmoreresults var load_more_staff ajax load_more_staff isonscreen if load_more_staff true loadmorestaff what am i doing wrong can you only fire one event from window scroll i assume not ',
#  'javascript jquery']

# %%
 sentence, tags = pair
                # слова вопроса, это как раз признаки x
sentence = sentence.split(' ')
                # теги вопроса, это y
tags = set(tags.split(' '))

# %%
for tag in _tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
    z = 0
   
    for word in sentence:
        if word not in _vocab:
            _vocab[word] = len(self._vocab)
        z += self._w[tag][_vocab[word]]
# Out:
# ['i',
#  've',
#  'got',
#  'some',
#  'code',
#  'in',
#  'window',
#  'scroll',
#  'that',
#  'checks',
#  'if',
#  'an',
#  'element',
#  'is',
#  'visible',
#  'then',
#  'triggers',
#  'another',
#  'function',
#  'however',
#  'only',
#  'the',
#  'first',
#  'section',
#  'of',
#  'code',
#  'is',
#  'firing',
#  'both',
#  'bits',
#  'of',
#  'code',
#  'work',
#  'in',
#  'and',
#  'of',
#  'themselves',
#  'if',
#  'i',
#  'swap',
#  'their',
#  'order',
#  'whichever',
#  'is',
#  'on',
#  'top',
#  'fires',
#  'correctly',
#  'my',
#  'code',
#  'is',
#  'as',
#  'follows',
#  'fn',
#  'isonscreen',
#  'function',
#  'use',
#  'strict',
#  'var',
#  'win',
#  'window',
#  'viewport',
#  'top',
#  'win',
#  'scrolltop',
#  'left',
#  'win',
#  'scrollleft',
#  'bounds',
#  'this',
#  'offset',
#  'viewport',
#  'right',
#  'viewport',
#  'left',
#  '+',
#  'win',
#  'width',
#  'viewport',
#  'bottom',
#  'viewport',
#  'top',
#  '+',
#  'win',
#  'height',
#  'bounds',
#  'right',
#  'bounds',
#  'left',
#  '+',
#  'this',
#  'outerwidth',
#  'bounds',
#  'bottom',
#  'bounds',
#  'top',
#  '+',
#  'this',
#  'outerheight',
#  'return',
#  'viewport',
#  'right',
#  'lt',
#  'bounds',
#  'left',
#  'viewport',
#  'left',
#  'gt',
#  'bounds',
#  'right',
#  'viewport',
#  'bottom',
#  'lt',
#  'bounds',
#  'top',
#  'viewport',
#  'top',
#  'gt',
#  'bounds',
#  'bottom',
#  'window',
#  'scroll',
#  'function',
#  'use',
#  'strict',
#  'var',
#  'load_more_results',
#  'ajax',
#  'load_more_results',
#  'isonscreen',
#  'if',
#  'load_more_results',
#  'true',
#  'loadmoreresults',
#  'var',
#  'load_more_staff',
#  'ajax',
#  'load_more_staff',
#  'isonscreen',
#  'if',
#  'load_more_staff',
#  'true',
#  'loadmorestaff',
#  'what',
#  'am',
#  'i',
#  'doing',
#  'wrong',
#  'can',
#  'you',
#  'only',
#  'fire',
#  'one',
#  'event',
#  'from',
#  'window',
#  'scroll',
#  'i',
#  'assume',
#  'not',
#  '']

# %%
_w['jquery']
# Out:
# defaultdict(int, {})

# %%
np.exp(1)
# Out:
# 2.7182818284590451

# %%
z = -706
print(np.exp(-z))
# Out:
# 4.09170414163e+306

# %%
np.log(1e-16)
# Out:
# -36.841361487904734

# %%
1 / (1+np.exp(706))
# Out:
# 2.443969469407077e-307

# %%
np.max([1 / (1+np.exp(706)),1e-16])
# Out:
# 9.9999999999999998e-17

# %%
DS_FILE_NAME2 = 'C:/Users/AgileDeveloper/data.hw4/stackoverflow_sample_2.tsv'

# %%
DS_FILE_NAME56 = 'C:/Users/AgileDeveloper/data.hw4/stackoverflow_sample_56.tsv'

# %%
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16):
        
        self._loss = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]]
                       # print(z)
    
                    # вычисляем вероятность наличия тега
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    if z<-706:
                        sigma = 1 / (1+np.exp(706))
                    else:
                        sigma = 1 / (1+np.exp(-z))
    
                    
                    # обновляем значение функции потерь для текущего примера
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sample_loss += y*np.log(np.max([sigma,tolerance]))+(1-y)*np.log(np.max([1-sigma,tolerance]))
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                        dLdw = (y-sigma)

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= -learning_rate*dLdw
                        self._b[tag] -= -learning_rate*dLdw
                    
                n += 1
                        
                self._loss.append(sample_loss)

# %%
# создадим эксемпляр модели и пройдемся по датасету
model = LogRegressor()
#model.iterate_file(top_n_train=1, fname=DS_FILE_NAME2, total=2)
model.iterate_file()
# Out:
# A Jupyter Widget

# %% [markdown]
# Проверим, действительно ли значение отрицательного логарифмического правдоподобия уменьшалось. Так как мы используем стохастический градентный спуск, не стоит ожидать плавного падения функции ошибки. Мы воспользуемся скользящим средним с окном в 10 тысяч примеров, чтобы хоть как-то сгладить график.

# %%
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());

# %%
model._w['php'][model._vocab['php']]
# Out:
# 81.687767349419602

# %%
plt.plot(pd.Series(map(lambda x: 0-x, model._loss[:-25000])).rolling(10000).mean());

# %%
 model._w['php'][model._vocab['python']]
# Out:
# -21.623429294107169

# %%
np.mean(model._loss[-35000:-25000])
# Out:
# -0.014547668330427194

# %%
print('Mean of the loss function on the last 10k train samples: %0.2f' % np.mean(model._loss[-35000:-25000]))
# Out:
# Mean of the loss function on the last 10k train samples: -19.59

# %%
pd.Series(map(lambda x: x**2, (model._loss[-35000:-25000]))).mean()
# Out:
# 1091.456302705359

# %%
[19.59-18.64,19.74-19.59]
# Out:
# [0.9499999999999993, 0.14999999999999858]

# %% [markdown]
# <font color="red">Вопрос 3.</font>
# Вычислите среднее значение функции стоимости на последних 10 000 примеров тренировочного набора, к какому из значений ваш ответ ближе всего?
#
# <font color="red">Варианты ответа:</font>
# 1. 17.54
# 2. 18.64
# 3. 19.74
# 4. 20.84

# %%
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16):
        
        self._loss = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]]
                       # print(z)
    
                    # вычисляем вероятность наличия тега
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    if z<-706:
                        sigma = 1 / (1+np.exp(706))
                    else:
                        sigma = 1 / (1+np.exp(-z))
    
                    
                    # обновляем значение функции потерь для текущего примера
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sample_loss += -(y*np.log(np.max([sigma,tolerance]))+(1-y)*np.log(np.max([1-sigma,tolerance])))
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                        dLdw = (y-sigma)

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= -learning_rate*dLdw
                        self._b[tag] -= -learning_rate*dLdw
                    
                n += 1
                        
                self._loss.append(sample_loss)

# %%
# создадим эксемпляр модели и пройдемся по датасету
model = LogRegressor()
model.iterate_file()
# Out:
# A Jupyter Widget

# %%
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());

# %%
print('Mean of the loss function on the last 10k train samples: %0.2f' % np.mean(model._loss[-35000:-25000]))
# Out:
# Mean of the loss function on the last 10k train samples: 19.59

# %% [markdown]
# ## 4. Тестирование модели
#
# В базовой модели первые 100 000 строк используются для обучения, а оставшиеся – для тестирования. Как вы можете заметить, значение отрицательного логарифмического правдоподобия не очень информативно, хоть и позволяет сравнивать разные модели. В качестве четвертого задания вам необходимо модифицировать базовую модель таким образом, чтобы метод `iterate_file` возвращал значение _точности_ на тестовой части набора данных.
#
# Точность определим следующим образом:
# - считаем, что тег у вопроса присутствует, если спрогнозированная вероятность тега больше 0.9
# - точность одного примера расчитывается как [коэффициент Жаккара](https://ru.wikipedia.org/wiki/Коэффициент_Жаккара) между множеством настоящих тегов и предсказанных моделью
#   - например, если у примера настоящие теги ['html', 'jquery'], а по версии модели ['ios', 'html', 'java'], то коэффициент Жаккара будет равен |['html', 'jquery'] $\cap$ ['ios', 'html', 'java']| / |['html', 'jquery'] $\cup$ ['ios', 'html', 'java']| = |['html']| / |['jquery', 'ios', 'html', 'java']| = 1/4
# - метод `iterate_file` возвращает **среднюю** точность на тестовом наборе данных

# %%
def sigmafunc(zpar):
    if zpar<-706:
        return 1 / (1+np.exp(706))
    else:
        return 1 / (1+np.exp(-zpar))

# %%
sigmafunc(+1000)
# Out:
# 1.0

# %%
a=['html', 'jquery']

# %%
b=['ios', 'html', 'jquery']

# %%
yt=0
for tag in b: 
    yt += int(tag in a)
res = yt/len(set(a+b))

# %%
res
# Out:
# 0.6666666666666666

# %%
set((set([1, 2]) | set([3, 4])))
# Out:
# {1, 2, 3, 4}

# %%
set([1, 2])+set([3, 4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-c726323a01cb> in <module>()
# ----> 1 set([1, 2])+set([3, 4])
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
# Обновите определение класса LogRegressor
# Ваш код здесь
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16):
        
        self._loss = []
        self._res = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                self._result_tag = []
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    z = self._b[tag]
                    
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]]
                       # print(z)
    
                    # вычисляем вероятность наличия тега
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sigma = sigmafunc(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sample_loss += y*np.log(np.max([sigma,tolerance]))+(1-y)*np.log(np.max([1-sigma,tolerance]))
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                        dLdw = (y-sigma)

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= -learning_rate*dLdw
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        zp=0
                        for word in sentence:
                            if word not in self._vocab:
                                continue
                            zp += self._w[tag][self._vocab[word]]
                        p = sigmafunc(zp)
                        if p>0.9:
                            self._result_tag.append(tag)
                if n >= top_n_train:
                    yt=0
                    for tag in tags: 
                        yt += int(tag in self._result_tag)  
                    res = yt/len(set(tags|set(self._result_tag)))
                    self._res.append(res)
                n += 1
                        
                self._loss.append(sample_loss)
        return np.mean(self._res)

# %%
model._res[25000-1]
# Out:
# 0.25

# %%
model._result_tag
# Out:
# ['php', 'html', 'jquery']

# %%
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());

# %%
model = LogRegressor()
acc = model.iterate_file()
# выведем полученное значение с точностью до двух знаков
print('%0.2f' % acc)
# Out:
# A Jupyter Widget
# 0.58

# %% [markdown]
# <font color="red">Вопрос 4.</font> К какому значению ближе всего полученное значение точности?
# <font color="red">Варианты ответа:</font>
# 1. 0.39
# 2. 0.49
# 3. 0.59
# 4. 0.69

# %% [markdown]
# ## 5. $L_2$-регуляризация
#
# В качестве пятого задания вам необходимо добавить в класс `LogRegressor` поддержку $L_2$-регуляризации. В методе `iterate_file` должен появиться параметр `lmbda=0.01` со значением по умолчанию. С учетом регуляризации новая функция стоимости примет вид:
#
# $$\large \begin{array}{rcl}
# L &=& -\mathcal{L} + \frac{\lambda}{2} R\left(\textbf W\right) \\
# &=& -\mathcal{L} + \frac{\lambda}{2} \sum_{k=1}^K\sum_{i=1}^M w_{ki}^2
# \end{array}$$
#
# Градиент первого члена суммы мы уже вывели, а для второго он имеет вид:
#
# $$\large \begin{array}{rcl}
# \frac{\partial}{\partial w_{ki}} \frac{\lambda}{2} R\left(\textbf W\right) &=& \lambda w_{ki}
# \end{array}$$
#
# Если мы на каждом примере будем делать честное обновление всех весов, то все очень замедлится, ведь нам придется на каждой итерации пробегать по всем словам словаря. В ущерб теоретической корректности мы используем грязный трюк: будем регуляризировать только те слова, которые присутствуют в текущем предложении. Не забывайте, что смещение (bias) не регуляризируется. `sample_loss` тоже должен остаться без изменений.
#
# Замечание:
# - не забудьте, что нужно учитывать регуляризацию слова в градиентном шаге только один раз
# - условимся, что учитываем регуляризацию только при первой встрече слова
# - если бы мы считали сначала bag-of-words, то мы бы в цикле шли по уникальным словам, но т.к. мы этого не делаем, приходится выкручиваться (еще одна жертва богу online-моделей)

# %%
# Обновите определение класса LogRegressor
# Ваш код здесь
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16,
                     lmbda=0.01):
        
        self._loss = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    z = self._b[tag]
   
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]]
                       # print(z)
    
                    # вычисляем вероятность наличия тега
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sigma = sigmafunc(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sample_loss += -(y*np.log(np.max([sigma,tolerance]))+(1-y)*np.log(np.max([1-sigma,tolerance])))
                    #+lmbda/2*sum(map(lambda x: x**2, self._w[tag].values()))
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                        dLdw = (y-sigma)

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= learning_rate*(-dLdw+lmbda*self._w[tag][self._vocab[word]])
                        self._b[tag] -= -learning_rate*dLdw
                    
                n += 1
                        
                self._loss.append(sample_loss)

# %%
# Обновите определение класса LogRegressor
# Ваш код здесь
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16,
                     lmbda=0.01):
        
        self._loss = []
        self._res = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                self._result_tag = []
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    z = self._b[tag]
                    
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]]
                       # print(z)
    
                    # вычисляем вероятность наличия тега
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sigma = sigmafunc(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sample_loss += y*np.log(np.max([sigma,tolerance]))+(1-y)*np.log(np.max([1-sigma,tolerance]))
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                        dLdw = (y-sigma)

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= learning_rate*(-dLdw+lmbda*self._w[tag][self._vocab[word]])
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        zp=0
                        for word in sentence:
                            if word not in self._vocab:
                                continue
                            zp += self._w[tag][self._vocab[word]]
                        p = sigmafunc(zp)
                        if p>0.9:
                            self._result_tag.append(tag)
                if n >= top_n_train:
                    yt=0
                    for tag in tags: 
                        yt += int(tag in self._result_tag)  
                    res = yt/len(set(tags|set(self._result_tag)))
                    self._res.append(res)
                n += 1
                        
                self._loss.append(sample_loss)
        return np.mean(self._res)

# %%
model = LogRegressor()
acc = model.iterate_file()
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# A Jupyter Widget
# 0.53

# %% [markdown]
# <font color="red">Вопрос 5.</font> К какому значению ближе всего полученное значение точности?
# <font color="red">Варианты ответа:</font>
# 1. 0.3
# 2. 0.35
# 3. 0.4
# 4. 0.52

# %% [markdown]
# ## 6. ElasticNet регуляризация, вывод
# Помимо $L_2$ регуляризации, часто используется $L_1$ регуляризация.
#
# $$\large \begin{array}{rcl}
# L &=& -\mathcal{L} + \frac{\lambda}{2} R\left(\textbf W\right) \\
# &=& -\mathcal{L} + \lambda \sum_{k=1}^K\sum_{i=1}^M \left|w_{ki}\right|
# \end{array}$$
#
# Если линейно объединить $L_1$ и $L_2$ регуляризацию, то полученный тип регуляризации называется ElasticNet:
#
# $$\large \begin{array}{rcl}
# L &=& -\mathcal{L} + \lambda R\left(\textbf W\right) \\
# &=& -\mathcal{L} + \lambda \left(\gamma \sum_{k=1}^K\sum_{i=1}^M w_{ki}^2 + \left(1 - \gamma\right) \sum_{k=1}^K\sum_{i=1}^M \left|w_{ki}\right| \right)
# \end{array}$$
# - где $\gamma \in \left[0, 1\right]$
#
# В качестве шестого вопроса вам предлагается вывести формулу градиента ElasticNet регуляризации (не учитывая $-\mathcal{L}$).
#
# <font color="red">Варианты ответа:</font>:
# 1. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(\textbf W\right) = \lambda \left(2 \gamma w_{ki} + \left(1 - \gamma\right) w_{ki}\right)$
# 2. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(\textbf W\right) = \lambda \left(2 \gamma \left|w_{ki}\right| + \left(1 - \gamma\right) \text{sign}\left(w_{ki}\right)\right)$
# 3. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(\textbf W\right) = \lambda \left(2 \gamma w_{ki} + \left(1 - \gamma\right) \text{sign}\left(w_{ki}\right)\right)$
# 4. $\large \frac{\partial}{\partial w_{ki}} \lambda R\left(\textbf W\right) = \lambda \left(\gamma w_{ki} + \left(1 - \gamma\right) \text{sign}\left(w_{ki}\right)\right)$

# %% [markdown]
# ## 7. Регуляризация ElasticNet , реализация
#
# В качестве седьмой задачи вам предлается изменить класс `LogRegressor` таким образом, чтобы метод `iterate_file` принимал два параметра со значениями по умолчанию `lmbda=0.0002` и `gamma=0.1`. Сделайте один проход по датасету с включенной `ElasticNet`-регуляризацией и заданными значениями по умолчанию и ответьте на вопрос.

# %%
# Обновите определение класса LogRegressor
# Ваш код здесь
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        
        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16,
                     lmbda=0.0002,
                    gamma=0.1):
        
        self._loss = []
        self._res = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                self._result_tag = []
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    z = self._b[tag]
                    
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if n >= top_n_train and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                        z += self._w[tag][self._vocab[word]]
                       # print(z)
    
                    # вычисляем вероятность наличия тега
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sigma = sigmafunc(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sample_loss += y*np.log(np.max([sigma,tolerance]))+(1-y)*np.log(np.max([1-sigma,tolerance]))
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                        dLdw = (y-sigma)

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:                        
                            self._w[tag][self._vocab[word]] -= learning_rate*(-dLdw+
                                lmbda*(2*gamma*self._w[tag][self._vocab[word]]+(1-gamma)*np.sign(self._w[tag][self._vocab[word]])))
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        zp=0
                        for word in sentence:
                            if word not in self._vocab:
                                continue
                            zp += self._w[tag][self._vocab[word]]
                        p = sigmafunc(zp)
                        if p>0.9:
                            self._result_tag.append(tag)
                if n >= top_n_train:
                    yt=0
                    for tag in tags: 
                        yt += int(tag in self._result_tag)  
                    res = yt/len(set(tags|set(self._result_tag)))
                    self._res.append(res)
                n += 1
                        
                self._loss.append(sample_loss)
        return np.mean(self._res)

# %%
model = LogRegressor()
acc = model.iterate_file()
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# A Jupyter Widget
# 0.56

# %% [markdown]
# <font color="red">Вопрос 7.</font> К какому значению ближе всего полученное значение точности:
# <font color="red">Варианты ответа:</font>
# 1. 0.59
# 2. 0.69
# 3. 0.79
# 4. 0.82

# %% [markdown]
# ## 8. Самые важные слова для тега
#
# Прелесть линейных моделей в том, что они легко интерпретируемы. Вам предлагается вычислить, какие слова вносят наибольший вклад в вероятность появления каждого из тегов. А затем ответьте на контрольный вопрос.

# %%
# Ваш код здесь
model._vocab.keys()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
model._vocab_inv = dict([(v, k) for (k, v) in model._vocab.items()])

for tag in model._tags:
    print(tag, ':', ', '.join([model._vocab_inv[k] for (k, v) in 
                               sorted(model._w[tag].items(), 
                                      key=lambda t: t[1], 
                                      reverse=True)[:5]]))
# Out:
# c++ : avrf, c++, std, cout, const
# php : php, _post, x5c, 125, echo
# java : println, servlet, hibernate, spring, jsp
# html : 3, br, lt, html, span
# c# : xsl, writeline, net, binding, linq
# jquery : jquery, ready, ajax, span, li
# python : python, def, py, 00, django
# android : android, activity, art, imgsrv, 29297
# ios : ios, nil, nsstring, xcode, iphone
# javascript : javascript, x20, 3, 125, getelementbyid

# %% [markdown]
# <font color="red">Вопрос 8.</font> Для многих тегов наличие самого тега в предложении является важным сигналом, у многих сам тег является самым сильным сигналом, что не удивительно. Для каких из тегов само название тега не входит в топ-5 самых важных?
#
# <font color="red">Варианты ответа:</font>
# 1. c#
# 2. javascript
# 3. jquery
# 4. android

# %% [markdown]
# ## 9. Сокращаем размер словаря
# Сейчас количество слов в словаре – 519290, если бы это была выборка из 10 миллионов вопросов с сайта StackOverflow, то размер словаря был бы миллионов 10. Регуляризировать модель можно не только изящно математически, но и топорно, например, ограничить размер словаря. Вам предоставляется возможность внести следующие изменения в класс `LogRegressor`:
# - добавить в метод `iterate_file` еще один аргумент со значением по умолчанию `update_vocab=True`
# - при `update_vocab=True` разрешать добавлять слова в словарь в режиме обучения
# - при `update_vocab=False` игнорировать слова не из словаря
# - добавить в класс метод `filter_vocab(n=10000)`, который оставит в словаре только топ-n самых популярных слов, используя данные из ``train``

# %%
# Обновите определение класса LogRegressor
# Ваш код здесь
# Обновите определение класса LogRegressor
# Ваш код здесь
class LogRegressor():
    
    """Конструктор
    
    Параметры
    ----------
    tags : list of string, default=top_tags
        список тегов
    """
    def __init__(self, tags=top_tags):      
        # словарь который содержит мапинг слов предложений и тегов в индексы (для экономии памяти)
        # пример: self._vocab['exception'] = 17 означает что у слова exception индекс равен 17
        self._vocab = {}
        self._vocab_freq = {}

        # параметры модели: веса
        # для каждого класса/тега нам необходимо хранить собственный вектор весов
        # по умолчанию у нас все веса будут равны нулю
        # мы заранее не знаем сколько весов нам понадобится
        # поэтому для каждого класса мы сосздаем словарь изменяемого размера со значением по умолчанию 0
        # пример: self._w['java'][self._vocab['exception']]  содержит вес для слова exception тега java
        self._w = dict([(t, defaultdict(int)) for t in tags])
        
        # параметры модели: смещения или вес w_0
        self._b = dict([(t, 0) for t in tags])
        
        self._tags = set(tags)
    
    def filter_vocab(self,n=10000):
        self._vocab_tmp = dict([(v, k) for (k, v) in self._vocab.items()])

        top = sorted(self._vocab_freq.items(), 
                                              key=lambda t: t[1], 
                                              reverse=True)[:n]
        top_dict = dict([(k, v) for (k, v) in top])
        
        keys = set(self._vocab.keys())
        for word in keys:
            if word not in top_dict:
                del self._vocab[word]
                
    """Один прогон по датасету
    
    Параметры
    ----------
    fname : string, default=DS_FILE_NAME
        имя файла с данными
        
    top_n_train : int
        первые top_n_train строк будут использоваться для обучения, остальные для тестирования
        
    total : int, default=10000000
        информация о количестве строк в файле для вывода прогресс бара
    
    learning_rate : float, default=0.1
        скорость обучения для градиентного спуска
        
    tolerance : float, default=1e-16
        используем для ограничения значений аргумента логарифмов
    """
    def iterate_file(self, 
                     fname=DS_FILE_NAME, 
                     top_n_train=100000, 
                     total=125000,
                     learning_rate=0.1,
                     tolerance=1e-16,
                     lmbda=0.0002,
                    gamma=0.1,
                    update_vocab=True):
        
        self._loss = []
        self._res = []
        n = 0
        
        # откроем файл
        with open(fname, 'r') as f:            
            
            
            # прогуляемся по строкам файла
            for line in tqdm_notebook(f, total=total, mininterval=1):
                self._result_tag = []
                pair = line.strip().split('\t')
                if len(pair) != 2:
                    continue                
                sentence, tags = pair
                # слова вопроса, это как раз признаки x
                sentence = sentence.split(' ')
                # теги вопроса, это y
                tags = set(tags.split(' '))
                
                # значение функции потерь для текущего примера
                sample_loss = 0

                # прокидываем градиенты для каждого тега
                for tag in self._tags:
                    # целевая переменная равна 1 если текущий тег есть у текущего примера
                    y = int(tag in tags)
                    
                    # расчитываем значение линейной комбинации весов и признаков объекта
                    # инициализируем z
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    z = self._b[tag]
                    
                    for word in sentence:
                        # если в режиме тестирования появляется слово которого нет в словаре, то мы его игнорируем
                        if (n >= top_n_train or update_vocab == False) and word not in self._vocab:
                            continue
                        if word not in self._vocab:
                            self._vocab[word] = len(self._vocab)
                            self._vocab_freq[word] = 1
                        else:
                            self._vocab_freq[word] = self._vocab_freq[word]+1
                        z += self._w[tag][self._vocab[word]]
                       # print(z)
    
                    # вычисляем вероятность наличия тега
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sigma = sigmafunc(z)
    
                    
                    # обновляем значение функции потерь для текущего примера
                    # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                    sample_loss += y*np.log(np.max([sigma,tolerance]))+(1-y)*np.log(np.max([1-sigma,tolerance]))
                 
                    
                    # если мы все еще в тренировочной части, то обновим параметры
                    if n < top_n_train:
                        # вычисляем производную логарифмического правдоподобия по весу
                        # ЗАПОЛНИТЕ ПРОПУСКИ В КОДЕ
                        dLdw = (y-sigma)

                        # делаем градиентный шаг
                        # мы минимизируем отрицательное логарифмическое правдоподобие (второй знак минус)
                        # поэтому мы идем в обратную сторону градиента для минимизации (первый знак минус)
                        for word in sentence:  
                            if word not in self._vocab:
                                continue
                            self._w[tag][self._vocab[word]] -= learning_rate*(-dLdw+
                                lmbda*(2*gamma*self._w[tag][self._vocab[word]]+(1-gamma)*np.sign(self._w[tag][self._vocab[word]])))
                        self._b[tag] -= -learning_rate*dLdw
                    else:
                        zp=0
                        for word in sentence:
                            if word not in self._vocab:
                                continue
                            zp += self._w[tag][self._vocab[word]]
                        p = sigmafunc(zp)
                        if p>0.9:
                            self._result_tag.append(tag)
                if n >= top_n_train:
                    yt=0
                    for tag in tags: 
                        yt += int(tag in self._result_tag)  
                    res = yt/len(set(tags|set(self._result_tag)))
                    self._res.append(res)
                n += 1
                        
                self._loss.append(sample_loss)
        return np.mean(self._res)

# %%
model = LogRegressor()
acc = model.iterate_file(update_vocab=True)
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# A Jupyter Widget
# 0.56

# %%
len(model._vocab)
# Out:
# 519290

# %%
_vocab_tmp = dict([(v, k) for (k, v) in model._vocab.items()])

# %%
model._vocab_freq
# Out:
# {'i': 6382720,
#  've': 208060,
#  'got': 79700,
#  'some': 358730,
#  'code': 806830,
#  'in': 2396460,
#  'window': 124770,
#  'scroll': 35980,
#  'that': 1369120,
#  'checks': 10410,
#  'if': 1450440,
#  'an': 641900,
#  'element': 122880,
#  'is': 2785680,
#  'visible': 39000,
#  'then': 291050,
#  'triggers': 6790,
#  'another': 116510,
#  'function': 807740,
#  'however': 139690,
#  'only': 256310,
#  'the': 7083710,
#  'first': 228540,
#  'section': 48820,
#  'of': 1720390,
#  'firing': 3100,
#  'both': 82490,
#  'bits': 9890,
#  'work': 231980,
#  'and': 2378590,
#  'themselves': 2480,
#  'swap': 5710,
#  'their': 52820,
#  'order': 87350,
#  'whichever': 810,
#  'on': 982670,
#  'top': 135050,
#  'fires': 4230,
#  'correctly': 42480,
#  'my': 1193040,
#  'as': 747470,
#  'follows': 30340,
#  'fn': 8000,
#  'isonscreen': 70,
#  'use': 406770,
#  'strict': 6050,
#  'var': 572580,
#  'win': 10170,
#  'viewport': 9750,
#  'scrolltop': 5870,
#  'left': 169950,
#  'scrollleft': 840,
#  'bounds': 12930,
#  'this': 2345960,
#  'offset': 22470,
#  'right': 178460,
#  '+': 881140,
#  'width': 279620,
#  'bottom': 61010,
#  'height': 220560,
#  'outerwidth': 560,
#  'outerheight': 970,
#  'return': 660590,
#  'lt': 6732220,
#  'gt': 7294330,
#  'load_more_results': 30,
#  'ajax': 104470,
#  'true': 429660,
#  'loadmoreresults': 10,
#  'load_more_staff': 30,
#  'loadmorestaff': 10,
#  'what': 466470,
#  'am': 660770,
#  'doing': 103930,
#  'wrong': 104730,
#  'can': 815730,
#  'you': 360470,
#  'fire': 9380,
#  'one': 342940,
#  'event': 163610,
#  'from': 786160,
#  'assume': 15000,
#  'not': 860540,
#  '': 1250000,
#  'have': 1141850,
#  'a': 3572320,
#  'custom': 67310,
#  'adapter': 31940,
#  'for': 1424930,
#  'list': 344050,
#  'view': 397420,
#  'it': 1832000,
#  'has': 253120,
#  '3': 480240,
#  'fields': 53910,
#  'thumbnail': 9990,
#  'two': 149440,
#  'text': 614610,
#  'once': 48550,
#  'layout': 108170,
#  'inflated': 760,
#  'thumbnails': 3420,
#  'are': 430000,
#  'downloaded': 12740,
#  'external': 24600,
#  'server': 246960,
#  'how': 592840,
#  'do': 546690,
#  'change': 143220,
#  'functionality': 18810,
#  'so': 600660,
#  'images': 117330,
#  'when': 636020,
#  'user': 390170,
#  'scrolls': 3460,
#  'down': 56680,
#  'override': 183870,
#  'public': 888200,
#  'getview': 7040,
#  'int': 660170,
#  'position': 148690,
#  'convertview': 17920,
#  'viewgroup': 32410,
#  'parent': 89050,
#  'inflate': 23710,
#  'layoutinflater': 31660,
#  'inflater': 17780,
#  'context': 170910,
#  'getsystemservice': 8660,
#  'layout_inflater_service': 2710,
#  'rowview': 2180,
#  'r': 311620,
#  'list_single': 40,
#  'false': 286000,
#  'imageview': 43590,
#  'image': 276060,
#  'findviewbyid': 79360,
#  'id': 934780,
#  'picture': 25440,
#  'textview': 90370,
#  'firstline': 280,
#  'secondline': 70,
#  'get': 688270,
#  'information': 73130,
#  'about': 139200,
#  'report': 19320,
#  'animallocationlog': 10,
#  'current': 94820,
#  'objects': 68040,
#  'all': 405610,
#  'important': 21240,
#  'string': 947970,
#  'species': 870,
#  'getspecies': 20,
#  'sanitizedspecies': 20,
#  'mischelpers': 10,
#  'sanitizestring': 40,
#  'reportid': 320,
#  'gettrackerid': 10,
#  'construct': 7030,
#  'url': 257410,
#  'to': 4540660,
#  'imagelocation': 370,
#  'websiteurl': 90,
#  'separator': 4710,
#  'extension': 25820,
#  'display': 167900,
#  'downloader': 970,
#  'download': 34520,
#  'settext': 46410,
#  'spotted': 180,
#  'getdatetime': 280,
#  'tostring': 102580,
#  'yyyy': 11900,
#  'mm': 21870,
#  'dd': 20630,
#  'h': 120430,
#  'm': 641550,
#  'form': 295260,
#  'panel': 37100,
#  'added': 72080,
#  'checkbox': 53360,
#  'setting': 37540,
#  'stateful': 260,
#  'stateid': 650,
#  'loginpanelremeberme': 10,
#  'before': 98400,
#  'sending': 20800,
#  'save': 76810,
#  'state': 72120,
#  'calling': 34220,
#  'savestate': 280,
#  'other': 201920,
#  'componenets': 10,
#  'whe': 120,
#  'reload': 8530,
#  'page': 291930,
#  'they': 118960,
#  'recall': 820,
#  'previous': 29380,
#  'but': 1054890,
#  'alway': 150,
#  'start': 146120,
#  'unchecked': 4470,
#  'there': 433880,
#  'any': 438650,
#  'way': 288030,
#  'force': 12890,
#  'value': 630150,
#  'dates': 11920,
#  'variables': 39030,
#  'startwork': 60,
#  'endwork': 40,
#  'need': 291310,
#  'define': 37350,
#  'whether': 24550,
#  'person': 37720,
#  'includes': 14300,
#  'worked': 26090,
#  'period': 6850,
#  '23': 56460,
#  'hours': 20710,
#  '05': 68810,
#  'example': 241350,
#  'hour': 12900,
#  'result': 224990,
#  '21': 49510,
#  '5': 323130,
#  'yes': 49050,
#  '22': 55350,
#  '12': 141290,
#  'no': 278310,
#  '8': 218740,
#  '7': 189270,
#  '9': 117720,
#  'amp': 575890,
#  'coverage': 2330,
#  'variants': 1240,
#  'might': 35680,
#  'been': 113420,
#  'using': 649360,
#  'search': 92490,
#  'tags': 28940,
#  'here': 434100,
#  'goes': 27550,
#  'app': 395820,
#  'developing': 19190,
#  'able': 109750,
#  'upload': 45950,
#  'pictures': 7040,
#  'videos': 8780,
#  'through': 89500,
#  'recording': 3950,
#  'or': 512520,
#  'gallery': 14390,
#  'currently': 63860,
#  'trying': 280370,
#  'show': 177780,
#  'video': 51360,
#  'which': 416990,
#  'just': 245160,
#  'recorded': 1990,
#  'taking': 11720,
#  'uri': 37610,
#  'intent': 137030,
#  'getdata': 9830,
#  'after': 184420,
#  'with': 974380,
#  'mediastore': 4070,
#  'action_video_capture': 60,
#  'void': 507380,
#  'getcameravideo': 10,
#  'takevideointent': 30,
#  'new': 1120170,
#  'resolveactivity': 170,
#  'ctx': 19790,
#  'getpackagemanager': 1030,
#  'null': 387710,
#  'startactivityforresult': 4080,
#  'fetcher_videocamera': 10,
#  'else': 291860,
#  'toast': 46900,
#  'maketext': 19240,
#  'language': 32900,
#  'translate': 12650,
#  'error_phone_has_no_camera_app': 10,
#  'length_long': 9830,
#  'errorclass': 430,
#  'log': 206810,
#  'tried': 209300,
#  'take': 46950,
#  'phone': 48760,
#  'camera': 34650,
#  'content': 242120,
#  'now': 224560,
#  'should': 232110,
#  'into': 213110,
#  'playing': 11340,
#  'videoview': 2630,
#  't': 775090,
#  'seem': 55290,
#  'find': 183870,
#  'decent': 1170,
#  'solution': 91070,
#  'issue': 91160,
#  'simply': 28880,
#  'activity': 126880,
#  'where': 255480,
#  'showing': 27950,
#  'results': 79860,
#  'black': 33110,
#  'setvideouri': 580,
#  'sure': 87650,
#  'someone': 58740,
#  'solved': 8140,
#  'already': 68820,
#  'collection': 33430,
#  'guaranteed': 1590,
#  'be': 738350,
#  'distinct': 5950,
#  'particular': 21900,
#  'indexed': 1750,
#  'by': 330020,
#  'unique': 18810,
#  'integer': 69830,
#  'also': 188470,
#  'know': 235520,
#  'exactly': 23850,
#  'many': 66480,
#  'them': 130560,
#  'number': 165000,
#  'won': 23630,
#  'was': 211280,
#  'wondering': 28350,
#  'array': 323010,
#  'would': 344790,
#  'notable': 170,
#  'performance': 16270,
#  'advantage': 2260,
#  'over': 61340,
#  'hashset': 5070,
#  'storing': 9440,
#  'retrieving': 4600,
#  'said': 13230,
#  'elements': 59060,
#  'paper': 4660,
#  'guarantees': 250,
#  'constant': 9390,
#  'time': 246660,
#  'insertion': 2480,
#  'since': 64770,
#  'size': 208770,
#  'ahead': 2300,
#  'retrieval': 650,
#  'looks': 67460,
#  'much': 55080,
#  'cleaner': 2070,
#  'adds': 13410,
#  'flexibility': 560,
#  'losing': 1280,
#  'anything': 50440,
#  'wise': 2420,
#  'at': 878770,
#  'least': 17850,
#  'theoretically': 590,
#  'below': 144950,
#  'problem': 291200,
#  'don': 171090,
#  'understand': 58990,
#  'why': 140540,
#  'refer': 6140,
#  'children': 29170,
#  'object': 320900,
#  'via': 50780,
#  'accessing': 6920,
#  'firstname': 27710,
#  'surname': 4950,
#  'please': 166420,
#  'help': 243450,
#  'me': 329280,
#  'sur': 250,
#  'age': 21600,
#  'getdisplayname': 400,
#  'gettotallength': 40,
#  'length': 154710,
#  'displayfullname': 10,
#  'changemaidenname': 10,
#  'newsurname': 40,
#  'addchild': 4920,
#  'childuser': 50,
#  'push': 39550,
#  'numberofchildren': 30,
#  'killchild': 20,
#  'foreach': 64620,
#  'item': 244510,
#  'index': 164590,
#  'splice': 1860,
#  '1': 1439950,
#  'module': 71740,
#  'exports': 5970,
#  'poster': 1910,
#  'sorry': 21000,
#  'too': 45950,
#  'long': 96030,
#  'hit': 13640,
#  'wall': 6800,
#  'try': 217670,
#  'making': 34220,
#  'matrices': 1890,
#  'calculator': 4110,
#  'c': 370040,
#  'wpf': 7690,
#  'spending': 570,
#  'last': 81150,
#  'figure': 49340,
#  'out': 377910,
#  's': 675200,
#  'iterator': 18900,
#  'edit': 115120,
#  'values': 159050,
#  '2d': 8790,
#  'nxn': 170,
#  'better': 47560,
#  'idea': 66630,
#  'project': 147910,
#  'far': 54950,
#  'requires': 14130,
#  'input': 355430,
#  'n': 242820,
#  'make': 191050,
#  'll': 24750,
#  'generate': 32720,
#  '0': 1844370,
#  'default': 112260,
#  'going': 47850,
#  'editing': 6420,
#  'whole': 29040,
#  '2': 790990,
#  'private': 313620,
#  'global': 30470,
#  'ints': 2210,
#  'keeps': 9040,
#  'track': 13240,
#  'row': 208250,
#  'column': 101790,
#  'manipulating': 870,
#  'these': 110130,
#  'numbers': 38500,
#  'part': 69270,
#  'iterations': 3230,
#  'starts': 18720,
#  'off': 37480,
#  'fine': 116960,
#  'instead': 74380,
#  'like': 538710,
#  'jumps': 1900,
#  'gone': 11840,
#  'countless': 240,
#  'times': 41360,
#  'logic': 19320,
#  'though': 32790,
#  'yet': 24350,
#  'test': 233850,
#  'traversing': 530,
#  'back': 82740,
#  'nearly': 2150,
#  'identical': 5190,
#  'assuming': 8240,
#  'same': 204080,
#  'problems': 28340,
#  'having': 78960,
#  'thanks': 206830,
#  'could': 160970,
#  'point': 83990,
#  'flawed': 360,
#  'move': 41670,
#  'onto': 8060,
#  'coding': 11870,
#  'up': 179800,
#  'parts': 14200,
#  'matrix': 26390,
#  'being': 80450,
#  'edited': 7810,
#  'set': 332120,
#  'made': 47900,
#  'col': 72460,
#  'previouspos_click': 10,
#  'sender': 49690,
#  'routedeventargs': 2760,
#  'e': 497620,
#  'console': 145170,
#  'writeline': 24270,
#  'textblock1': 60,
#  'positiondisplay': 60,
#  'setvalue': 8150,
#  'valuedisplay': 40,
#  'displaymatrix': 60,
#  'nextpos_click': 10,
#  '+row+': 70,
#  'ncol': 130,
#  '+col': 40,
#  'getlength': 2130,
#  'more': 139790,
#  'currow': 210,
#  'curcol': 180,
#  'parse': 56620,
#  'catch': 119070,
#  'exception': 158570,
#  'messageboxtext': 20,
#  'valid': 30780,
#  'caption': 8300,
#  'warning': 35990,
#  'messageboxbutton': 240,
#  'button': 335740,
#  'ok': 50010,
#  'messageboximage': 150,
#  'icon': 54720,
#  'messagebox': 9650,
#  'fixed': 26240,
#  'typo': 650,
#  'saw': 8660,
#  'willing': 1420,
#  'post': 163600,
#  'rest': 28620,
#  'request': 181540,
#  'syntax': 23650,
#  'response': 147340,
#  'appendheader': 170,
#  'refresh': 20360,
#  'ordres': 20,
#  'aspx': 19160,
#  'firefox': 23080,
#  'chrome': 37840,
#  'memorystream': 4260,
#  'ms': 23380,
#  'pdfexportoptions': 20,
#  'opts': 3950,
#  'showprintdialogonopen': 10,
#  'xtrareport_pricipal': 10,
#  'exporttopdf': 40,
#  'seek': 2050,
#  'seekorigin': 280,
#  'begin': 21410,
#  'byte': 55930,
#  'toarray': 5380,
#  'contenttype': 9180,
#  'application': 253180,
#  'pdf': 35190,
#  'clear': 44060,
#  'outputstream': 6670,
#  'write': 118320,
#  'httpcontext': 5990,
#  'applicationinstance': 60,
#  'completerequest': 80,
#  'finally': 20790,
#  'close': 102030,
#  'internet': 21230,
#  'explorer': 6480,
#  'redirect': 24380,
#  'sec': 7550,
#  'ie': 28950,
#  'advance': 66270,
#  'forum': 5100,
#  'ganglia': 70,
#  'we': 154170,
#  'capture': 10230,
#  'jvm': 6900,
#  'metrics': 2880,
#  'followed': 12150,
#  'steps': 11800,
#  'link': 143970,
#  'https': 91240,
#  'github': 22840,
#  'com': 561680,
#  'jmxetric': 140,
#  'high': 11650,
#  'level': 46510,
#  'installation': 7370,
#  'unzip': 1200,
#  'archive': 7700,
#  'add': 344420,
#  'following': 231330,
#  'your': 105470,
#  'java': 905920,
#  'javaagent': 390,
#  'path': 135380,
#  'jar': 72370,
#  'host': 37070,
#  'port': 36790,
#  'config': 71040,
#  'process': 84620,
#  'usual': 3070,
#  'main': 248110,
#  'class': 1246260,
#  'demo': 18250,
#  'quickstart': 890,
#  'works': 179030,
#  'version': 165770,
#  '6': 178660,
#  'gmetric4j': 30,
#  'ensure': 7260,
#  'gmond': 20,
#  'running': 84990,
#  'localhost': 49830,
#  '8649': 40,
#  'pgrep': 60,
#  'pid': 15010,
#  'nc': 4610,
#  'dumps': 2090,
#  'xml': 175050,
#  'stdout': 8110,
#  'git': 7100,
#  'clone': 8710,
#  'above': 85340,
#  'oncrpc': 20,
#  'directory': 56530,
#  'cd': 7360,
#  'bash': 3930,
#  'export': 15100,
#  'wireformat31x': 20,
#  'etc': 70060,
#  'djava': 830,
#  'util': 72620,
#  'logging': 20250,
#  'file': 615350,
#  'properties': 54070,
#  'cp': 4330,
#  '4': 356960,
#  'info': 114460,
#  'jmxetricagent': 40,
#  'argument': 23770,
#  'its': 119470,
#  'coming': 12940,
#  'native': 47710,
#  'sterr': 20,
#  'logs': 13000,
#  'shows': 49790,
#  'instrumented': 200,
#  'see': 162340,
#  'used': 124320,
#  'wakeup': 210,
#  'around': 44930,
#  'every': 80670,
#  '10': 276790,
#  'mints': 40,
#  'writing': 34170,
#  'instance': 67080,
#  'does': 205340,
#  'run': 221930,
#  'command': 73270,
#  'line': 267750,
#  'root': 63640,
#  'hostname': 5880,
#  'jmxmetric': 20,
#  'master': 17790,
#  'mode': 37490,
#  'unicast': 220,
#  'hostanem_m01': 10,
#  'getting': 119360,
#  'suggest': 16100,
#  'week': 9630,
#  'struggling': 6880,
#  'cooperate': 140,
#  'www': 136990,
#  'brief': 1630,
#  'send': 89130,
#  'data': 749770,
#  'he': 22580,
#  'connection': 100070,
#  'sendtoserver': 230,
#  'filename': 58890,
#  'extendedlog': 10,
#  'tag': 78550,
#  'httpurlconnection': 6830,
#  'dataoutputstream': 2570,
#  'datainputstream': 2160,
#  'inputstream': 16980,
#  'pathtoourfile': 30,
#  'unsenddirectory': 10,
#  'pathtocopyfile': 20,
#  'senddirectory': 10,
#  'copyfile': 360,
#  'lineend': 650,
#  'twohyphens': 320,
#  'boundary': 3870,
#  'bytesread': 2370,
#  'bytesavailable': 700,
#  'buffersize': 2240,
#  'buffer': 38620,
#  'maxbuffersize': 590,
#  '1024': 11980,
#  'fileinputstream': 7960,
#  'urlserver': 40,
#  'openconnection': 3470,
#  'allow': 32950,
#  'inputs': 13090,
#  'outputs': 9110,
#  'setdoinput': 600,
#  'setdooutput': 930,
#  'setusecaches': 350,
#  'enable': 20050,
#  'method': 366410,
#  'setrequestmethod': 1250,
#  'setrequestproperty': 1690,
#  'keep': 44630,
#  'alive': 4120,
#  'type': 545910,
#  'multipart': 7550,
#  '+boundary': 40,
#  'getoutputstream': 4020,
#  'writebytes': 1430,
#  'disposition': 4360,
#  'name': 823820,
#  'uploadedfile': 1610,
#  'available': 37040,
#  'math': 42740,
#  'min': 68490,
#  'read': 125040,
#  'while': 173280,
#  'responses': 4150,
#  'message': 190210,
#  'serverresponsecode': 90,
#  'getresponsecode': 1080,
#  'serverresponsemessage': 40,
#  'getresponsemessage': 130,
#  'flush': 10270,
#  'odpowiedz': 30,
#  'sendfileproblem': 40,
#  'append': 82570,
#  'fileoutputstream': 8490,
#  'f2': 5000,
#  'overwrite': 2940,
#  'buf': 7800,
#  'len': 27490,
#  'delete': 61950,
#  'ex': 38790,
#  'wyjatek': 10,
#  'getmessage': 12400,
#  'healthcareapplication': 10,
#  'shownotification': 260,
#  'drawable': 51970,
#  'occurred': 10470,
#  'php': 466640,
#  'target_path': 540,
#  'basename': 3020,
#  '_files': 12340,
#  'move_uploaded_file': 2250,
#  'tmp_name': 4260,
#  'echo': 197300,
#  'uploaded': 11550,
#  'error': 534640,
#  'uploading': 6630,
#  'again': 60420,
#  'really': 68470,
#  'dont': 22770,
#  'script': 318080,
#  'anyone': 96330,
#  'give': 45940,
#  'tip': 3870,
#  'microsoft': 39540,
#  'outlook': 3820,
#  'create': 224620,
#  'mail': 39570,
#  'template': 81410,
#  'existing': 21700,
#  'html': 385170,
#  'let': 86860,
#  'replace': 49210,
#  'created': 104260,
#  'virtual': 27890,
#  'enviroments': 70,
#  'vm': 13040,
#  'pip': 8050,
#  'freeze': 1990,
#  'installed': 28730,
#  'packages': 38000,
#  'output': 136570,
#  'requests': 25260,
#  'lib': 111200,
#  'different': 113160,
#  'makes': 24980,
#  'provide': 22480,
#  '13': 80570,
#  'security': 47390,
#  'urllib': 3280,
#  '20': 118130,
#  'python': 117900,
#  'laravel': 11860,
#  'environments': 1470,
#  'want': 469020,
#  'site': 83200,
#  'always': 55560,
#  'setup': 37060,
#  'comes': 23120,
#  'declare': 11080,
#  'env': 15720,
#  'detectenvironment': 10,
#  'local': 68960,
#  'mark': 12010,
#  'macbook': 1350,
#  'development': 19320,
#  'excelsior': 50,
#  'servers': 7890,
#  'prgn': 20,
#  'misp': 20,
#  'co': 11980,
#  'uk': 9300,
#  'production': 8270,
#  'files': 151690,
#  'correct': 67570,
#  'database': 170750,
#  'details': 37410,
#  'each': 193760,
#  'environment': 26220,
#  'database_host': 120,
#  'database_name': 2110,
#  'borough': 120,
#  'database_user': 130,
#  'database_password': 180,
#  'unix_socket': 60,
#  'applications': 16130,
#  'mamp': 1270,
#  'tmp': 20830,
#  'mysql': 59930,
#  'sock': 4600,
#  'db': 114440,
#  'pass': 65230,
#  'connections': 9020,
#  'driver': 29410,
#  '_env': 190,
#  'username': 105000,
#  'password': 116790,
#  'charset': 27580,
#  'utf8': 9390,
#  'collation': 590,
#  'utf8_unicode_ci': 790,
#  'prefix': 10070,
#  'usually': 7700,
#  'artisan': 1640,
#  'serve': 4230,
#  'errorexception': 390,
#  'undefined': 40480,
#  'freelance': 100,
#  'projects': 23960,
#  'build': 114150,
#  'cc': 12560,
#  '67': 6990,
#  'happen': 18100,
#  'may': 52260,
#  'cheers': 4110,
#  'linq': 15030,
#  'query': 162690,
#  'fill': 33510,
#  'cycle': 5210,
#  'slow': 14440,
#  'formentries': 50,
#  'f': 99080,
#  'bnetformentries': 10,
#  'join': 34160,
#  'bnetformstatus': 20,
#  'statusid': 300,
#  'equals': 37400,
#  'entrystatus': 20,
#  's2': 6130,
#  'externalstatusid': 30,
#  'entrystatus2': 20,
#  'formid': 1210,
#  'orderby': 5070,
#  'formentryid': 60,
#  'descending': 1940,
#  'select': 229260,
#  'formentry': 10,
#  'ipaddress': 3640,
#  'useragent': 1760,
#  'createdby': 1440,
#  'createddate': 1300,
#  'updatedby': 400,
#  'updateddate': 340,
#  'statustext': 890,
#  'firstordefault': 3320,
#  'status': 81150,
#  'externalstatustext': 10,
#  'tolist': 9650,
#  'x': 363090,
#  'count': 107720,
#  'x++': 4450,
#  'entryvalues': 220,
#  'elementat': 950,
#  'formentryvalue': 10,
#  'todictionary': 370,
#  'entry': 38320,
#  'definitely': 3460,
#  'faster': 8400,
#  'dynamically': 21650,
#  'alert': 88770,
#  'components': 15310,
#  'react': 15640,
#  'bootstrap': 33480,
#  'runtime': 32460,
#  'instantiating': 1390,
#  'javascript': 171020,
#  'classes': 56340,
#  'because': 129350,
#  'lots': 7750,
#  'alerts': 3380,
#  'succinct': 90,
#  'attempts': 4550,
#  'working': 176640,
#  'generally': 3390,
#  'applies': 2280,
#  'occurs': 13220,
#  'js': 223410,
#  'throws': 45680,
#  'typeerror': 11570,
#  'throw': 31490,
#  'getcomponent': 1480,
#  'call': 171330,
#  'jsx': 1210,
#  'dom': 19320,
#  'reactbootstrap': 30,
#  'alertdismissible': 40,
#  'createclass': 950,
#  'getinitialstate': 400,
#  'isvisible': 1210,
#  'render': 35660,
#  'props': 11540,
#  'bsstyle': 120,
#  'ondismiss': 200,
#  'dismissalert': 50,
#  'p': 266340,
#  'setstate': 2670,
#  'alertnotice': 80,
#  'prototype': 17180,
#  'go': 77060,
#  'doesn': 133960,
#  'successalert': 90,
#  'success': 68430,
#  'constructor': 41990,
#  'kinds': 1690,
#  'erroralert': 80,
#  'danger': 4020,
#  'somethingwithalerts': 20,
#  'goof': 30,
#  '123': 15430,
#  '321': 1500,
#  'map': 111920,
#  'div': 816210,
#  'testcomponent': 90,
#  'rendercomponent': 40,
#  'document': 185820,
#  'getelementbyid': 61540,
#  'component': 39290,
#  'library': 90960,
#  'extraneous': 200,
#  'found': 129440,
#  'necessary': 12130,
#  'satisfy': 1380,
#  'framework': 49630,
#  'reality': 990,
#  'instances': 12270,
#  'generating': 7360,
#  'nodes': 17730,
#  'proper': 14560,
#  'hint': 8090,
#  'hardcoded': 1850,
#  'without': 99700,
#  'duplicate': 17280,
#  '777': 2170,
#  'replacement': 2860,
#  'including': 13860,
#  'explains': 1660,
#  'key': 161780,
#  'child': 52750,
#  'prop': 15150,
#  'check': 104250,
#  'specimensetmanager': 10,
#  'http': 410350,
#  'fb': 9520,
#  'keys': 24760,
#  'inside': 86850,
#  'completeness': 540,
#  'source': 119800,
#  'boostrap': 180,
#  'v0': 1820,
#  '11': 128860,
#  'head': 78370,
#  'src': 201630,
#  'jsxtransformer': 20,
#  'rel': 32670,
#  'stylesheet': 26680,
#  'href': 195500,
#  'css': 151430,
#  'theme': 25970,
#  'body': 145200,
#  'trouble': 18910,
#  'understanding': 11830,
#  'short': 18350,
#  'hand': 11910,
#  'notation': 1740,
#  'seeing': 7560,
#  ...}

# %%
top = sorted(model._vocab_freq.items(), 
                                              key=lambda t: t[1], 
                                              reverse=True)[:10000]

# %%
len(model._vocab)
# Out:
# 10000

# %%
keys = set(model._vocab.keys())

# %%
len(keys)
# Out:
# 519287

# %%
'gt' not in top_dict
# Out:
# False

# %%
top_dict = dict([(k, v) for (k, v) in top])

# %%
top_dict
# Out:
# {'gt': 7294330,
#  'the': 7083710,
#  'lt': 6732220,
#  'i': 6382720,
#  'to': 4540660,
#  'a': 3572320,
#  'is': 2785680,
#  'in': 2396460,
#  'and': 2378590,
#  'this': 2345960,
#  '0': 1844370,
#  'it': 1832000,
#  'of': 1720390,
#  'if': 1450440,
#  '1': 1439950,
#  'for': 1424930,
#  'that': 1369120,
#  '': 1250000,
#  'class': 1246260,
#  'my': 1193040,
#  'android': 1157050,
#  'have': 1141850,
#  'new': 1120170,
#  'but': 1054890,
#  'on': 982670,
#  'with': 974380,
#  'string': 947970,
#  'id': 934780,
#  'java': 905920,
#  'public': 888200,
#  '+': 881140,
#  'at': 878770,
#  'not': 860540,
#  'name': 823820,
#  'div': 816210,
#  'can': 815730,
#  'function': 807740,
#  'code': 806830,
#  '2': 790990,
#  'from': 786160,
#  't': 775090,
#  'data': 749770,
#  'as': 747470,
#  'be': 738350,
#  'get': 688270,
#  's': 675200,
#  'am': 660770,
#  'return': 660590,
#  'int': 660170,
#  'using': 649360,
#  'an': 641900,
#  'm': 641550,
#  'when': 636020,
#  'value': 630150,
#  'file': 615350,
#  'text': 614610,
#  'so': 600660,
#  'how': 592840,
#  'amp': 575890,
#  'var': 572580,
#  'com': 561680,
#  'do': 546690,
#  'type': 545910,
#  'like': 538710,
#  'error': 534640,
#  'or': 512520,
#  'void': 507380,
#  'e': 497620,
#  '3': 480240,
#  'want': 469020,
#  'php': 466640,
#  'what': 466470,
#  'any': 438650,
#  'here': 434100,
#  'there': 433880,
#  'are': 430000,
#  'true': 429660,
#  'which': 416990,
#  'http': 410350,
#  'use': 406770,
#  'all': 405610,
#  'view': 397420,
#  'system': 396550,
#  'app': 395820,
#  'user': 390170,
#  'null': 387710,
#  'html': 385170,
#  'out': 377910,
#  'c': 370040,
#  'import': 367010,
#  'method': 366410,
#  'x': 363090,
#  'org': 360600,
#  'you': 360470,
#  'td': 360310,
#  'some': 358730,
#  '4': 356960,
#  'input': 355430,
#  'would': 344790,
#  'add': 344420,
#  'list': 344050,
#  'one': 342940,
#  'self': 338600,
#  'button': 335740,
#  'set': 332120,
#  'by': 330020,
#  'me': 329280,
#  '5': 323130,
#  'array': 323010,
#  'object': 320900,
#  'script': 318080,
#  'will': 316750,
#  'private': 313620,
#  'r': 311620,
#  'form': 295260,
#  'page': 291930,
#  'else': 291860,
#  'need': 291310,
#  'problem': 291200,
#  'then': 291050,
#  'way': 288030,
#  'false': 286000,
#  'li': 282510,
#  'trying': 280370,
#  'width': 279620,
#  'no': 278310,
#  '10': 276790,
#  'image': 276060,
#  'd': 273060,
#  'line': 267750,
#  'p': 266340,
#  'url': 257410,
#  'only': 256310,
#  'where': 255480,
#  'table': 254550,
#  'application': 253180,
#  'has': 253120,
#  'main': 248110,
#  'server': 246960,
#  'time': 246660,
#  'just': 245160,
#  'item': 244510,
#  'help': 243450,
#  'n': 242820,
#  'content': 242120,
#  'example': 241350,
#  'know': 235520,
#  'test': 233850,
#  'should': 232110,
#  'work': 231980,
#  'b': 231600,
#  'following': 231330,
#  'select': 229260,
#  'first': 228540,
#  'result': 224990,
#  'create': 224620,
#  'now': 224560,
#  'js': 223410,
#  'run': 221930,
#  'height': 220560,
#  '8': 218740,
#  'try': 217670,
#  'style': 216660,
#  'static': 216030,
#  'into': 213110,
#  'was': 211280,
#  'tried': 209300,
#  'size': 208770,
#  'row': 208250,
#  've': 208060,
#  'thanks': 206830,
#  'log': 206810,
#  'does': 205340,
#  'option': 205150,
#  'same': 204080,
#  'other': 201920,
#  'src': 201630,
#  'title': 201560,
#  'echo': 197300,
#  'href': 195500,
#  'color': 195020,
#  'each': 193760,
#  'make': 191050,
#  'message': 190210,
#  '7': 189270,
#  'also': 188470,
#  'label': 187970,
#  'click': 187900,
#  'document': 185820,
#  'jquery': 184520,
#  'after': 184420,
#  'override': 183870,
#  'find': 183870,
#  'request': 181540,
#  'y': 180950,
#  'up': 179800,
#  'something': 179440,
#  'works': 179030,
#  '6': 178660,
#  'span': 178660,
#  'right': 178460,
#  'show': 177780,
#  'working': 176640,
#  'xml': 175050,
#  'while': 173280,
#  'call': 171330,
#  'don': 171090,
#  'javascript': 171020,
#  'context': 170910,
#  'database': 170750,
#  'left': 169950,
#  'display': 167900,
#  'date': 166590,
#  'please': 166420,
#  'version': 165770,
#  'number': 165000,
#  'index': 164590,
#  'event': 163610,
#  'post': 163600,
#  'background': 163220,
#  'print': 163130,
#  'query': 162690,
#  'see': 162340,
#  'key': 161780,
#  'could': 160970,
#  'web': 160310,
#  'tr': 159860,
#  'json': 159490,
#  'values': 159050,
#  'exception': 158570,
#  'length': 154710,
#  'we': 154170,
#  'files': 151690,
#  'css': 151430,
#  'case': 150690,
#  'two': 149440,
#  'position': 148690,
#  'project': 147910,
#  'response': 147340,
#  'question': 146220,
#  'start': 146120,
#  'body': 145200,
#  'console': 145170,
#  'below': 144950,
#  '100': 144270,
#  'link': 143970,
#  'change': 143220,
#  '12': 141290,
#  'why': 140540,
#  'more': 139790,
#  'however': 139690,
#  'about': 139200,
#  'include': 139040,
#  'end': 138100,
#  'model': 137090,
#  'intent': 137030,
#  'www': 136990,
#  'output': 136570,
#  'path': 135380,
#  'top': 135050,
#  'doesn': 133960,
#  'std': 133650,
#  'br': 132880,
#  'google': 132300,
#  'them': 130560,
#  'img': 130450,
#  'println': 130000,
#  'found': 129440,
#  'because': 129350,
#  'open': 129350,
#  '11': 128860,
#  'update': 128570,
#  '00': 127690,
#  'activity': 126880,
#  'client': 126170,
#  'net': 125630,
#  'read': 125040,
#  'window': 124770,
#  'used': 124320,
#  'final': 123670,
#  'thread': 123650,
#  'element': 122880,
#  'api': 122700,
#  'h': 120430,
#  'email': 120110,
#  'source': 119800,
#  'its': 119470,
#  'getting': 119360,
#  'catch': 119070,
#  'apache': 119040,
#  'they': 118960,
#  'write': 118320,
#  '20': 118130,
#  'python': 117900,
#  '9': 117720,
#  'images': 117330,
#  'fine': 116960,
#  'password': 116790,
#  'another': 116510,
#  'users': 116260,
#  'property': 116000,
#  'action': 115730,
#  'edit': 115120,
#  'possible': 114610,
#  'info': 114460,
#  'db': 114440,
#  'build': 114150,
#  'program': 113430,
#  'been': 113420,
#  'different': 113160,
#  'menu': 113080,
#  'default': 112260,
#  'map': 111920,
#  'lib': 111200,
#  'load': 110390,
#  'these': 110130,
#  'service': 110100,
#  'able': 109750,
#  'lang': 108530,
#  'layout': 108170,
#  'count': 107720,
#  'ul': 106540,
#  'androidruntime': 105600,
#  'your': 105470,
#  'username': 105000,
#  'wrong': 104730,
#  'ajax': 104470,
#  'location': 104320,
#  'created': 104260,
#  'check': 104250,
#  'double': 104120,
#  'font': 104090,
#  'put': 104020,
#  'doing': 103930,
#  'header': 103770,
#  'tostring': 102580,
#  'j': 102480,
#  'close': 102030,
#  'column': 101790,
#  'none': 101380,
#  '15': 101370,
#  'next': 100320,
#  'access': 100090,
#  'connection': 100070,
#  'without': 99700,
#  'f': 99080,
#  'field': 98990,
#  'before': 98400,
#  'v': 97210,
#  'g': 96800,
#  'anyone': 96330,
#  'long': 96030,
#  '16': 95830,
#  'simple': 95640,
#  'current': 94820,
#  'os': 94470,
#  'second': 94190,
#  'called': 93880,
#  'items': 92800,
#  'search': 92490,
#  'float': 92470,
#  '01': 92440,
#  'controller': 91730,
#  'https': 91240,
#  'center': 91190,
#  'issue': 91160,
#  'solution': 91070,
#  'library': 90960,
#  'textview': 90370,
#  'margin': 90320,
#  'still': 90040,
#  'windows': 89620,
#  'through': 89500,
#  'variable': 89450,
#  'send': 89130,
#  'parent': 89050,
#  'alert': 88770,
#  'py': 88130,
#  'sure': 87650,
#  'layout_width': 87460,
#  'order': 87350,
#  'def': 87330,
#  'super': 87320,
#  'layout_height': 87290,
#  'submit': 86900,
#  'let': 86860,
#  'inside': 86850,
#  'ui': 86760,
#  'cannot': 86310,
#  'seems': 86080,
#  'format': 85960,
#  'const': 85920,
#  'i++': 85470,
#  'above': 85340,
#  'border': 85310,
#  'running': 84990,
#  'process': 84620,
#  'login': 84620,
#  'even': 84310,
#  'point': 83990,
#  'sql': 83570,
#  'site': 83200,
#  'control': 83190,
#  'break': 83110,
#  '14': 82920,
#  'th': 82900,
#  'support': 82880,
#  'than': 82820,
#  'back': 82740,
#  'container': 82620,
#  'png': 82610,
#  'append': 82570,
#  'both': 82490,
#  'box': 81540,
#  'template': 81410,
#  'extends': 81380,
#  'node': 81160,
#  'last': 81150,
#  'status': 81150,
#  'scope': 81080,
#  'loop': 80920,
#  '+id': 80780,
#  'every': 80670,
#  '13': 80570,
#  'being': 80450,
#  '_post': 79910,
#  'results': 79860,
#  'got': 79700,
#  'char': 79660,
#  'very': 79490,
#  '50': 79390,
#  'findviewbyid': 79360,
#  'session': 79260,
#  'options': 79000,
#  'having': 78960,
#  'wrap_content': 78840,
#  'tag': 78550,
#  'head': 78370,
#  'auto': 78260,
#  'screen': 78010,
#  'block': 77680,
#  'protected': 77610,
#  'w': 77160,
#  'go': 77060,
#  'core': 76900,
#  'boolean': 76850,
#  'save': 76810,
#  '30': 76790,
#  'done': 76560,
#  'o': 76280,
#  'remove': 75510,
#  'springframework': 74950,
#  'cell': 74840,
#  'instead': 74380,
#  'val': 74110,
#  'bar': 73830,
#  'command': 73270,
#  'information': 73130,
#  'home': 73120,
#  'arraylist': 72920,
#  'util': 72620,
#  'col': 72460,
#  'jar': 72370,
#  'state': 72120,
#  'added': 72080,
#  'insert': 71920,
#  'module': 71740,
#  'think': 71620,
#  'contains': 71440,
#  'frame': 71430,
#  'execute': 71290,
#  'asp': 71180,
#  'config': 71040,
#  'filter': 71020,
#  'rows': 70400,
#  'debug': 70260,
#  'etc': 70060,
#  'empty': 69960,
#  'integer': 69830,
#  'res': 69550,
#  'part': 69270,
#  'bundle': 69230,
#  'address': 69160,
#  'group': 69010,
#  '17': 69010,
#  'local': 68960,
#  'already': 68820,
#  '05': 68810,
#  'target': 68770,
#  'cout': 68680,
#  'args': 68570,
#  'min': 68490,
#  'really': 68470,
#  'success': 68430,
#  'selected': 68320,
#  'objects': 68040,
#  'returns': 67920,
#  'onclick': 67850,
#  'widget': 67830,
#  'correct': 67570,
#  'looks': 67460,
#  'custom': 67310,
#  'internal': 67290,
#  'instance': 67080,
#  'xmlns': 66710,
#  'enter': 66640,
#  'idea': 66630,
#  'many': 66480,
#  'advance': 66270,
#  '18': 66100,
#  'well': 65660,
#  'required': 65430,
#  '08': 65250,
#  'pass': 65230,
#  'such': 65190,
#  'padding': 65050,
#  'since': 64770,
#  'activitythread': 64760,
#  'foreach': 64620,
#  'description': 64250,
#  'currently': 63860,
#  'root': 63640,
#  'between': 63590,
#  '25': 63480,
#  'jpg': 63330,
#  'z': 63130,
#  'sun': 62810,
#  'attr': 62560,
#  'javax': 62540,
#  '09': 62300,
#  'appreciated': 62230,
#  'grid': 62170,
#  'delete': 61950,
#  'failed': 61950,
#  'align': 61890,
#  'store': 61800,
#  'connect': 61750,
#  'task': 61630,
#  'getelementbyid': 61540,
#  'device': 61490,
#  'over': 61340,
#  'bottom': 61010,
#  'answer': 60850,
#  'handler': 60690,
#  'oncreate': 60460,
#  'again': 60420,
#  'package': 60200,
#  'mysql': 59930,
#  '07': 59900,
#  'io': 59820,
#  'generated': 59800,
#  '02': 59780,
#  'browser': 59550,
#  'folder': 59160,
#  'multiple': 59150,
#  'elements': 59060,
#  'errors': 59040,
#  'understand': 58990,
#  'foo': 58960,
#  'filename': 58890,
#  'someone': 58740,
#  '03': 58590,
#  'btn': 58560,
#  'utf': 58460,
#  'thank': 58300,
#  'hidden': 57950,
#  'init': 57820,
#  'convert': 57780,
#  '04': 57670,
#  'reference': 57620,
#  'based': 57370,
#  'everything': 57290,
#  'within': 57000,
#  'l': 56840,
#  'u': 56840,
#  'website': 56740,
#  'down': 56680,
#  'parse': 56620,
#  'obj': 56600,
#  'directory': 56530,
#  '23': 56460,
#  'classes': 56340,
#  'byte': 55930,
#  'methods': 55660,
#  'always': 55560,
#  'str': 55460,
#  'must': 55400,
#  '22': 55350,
#  'plugin': 55350,
#  'seem': 55290,
#  'category': 55270,
#  'looking': 55160,
#  'product': 55090,
#  'much': 55080,
#  '19': 54970,
#  'far': 54950,
#  'savedinstancestate': 54950,
#  'dialog': 54880,
#  'icon': 54720,
#  'uses': 54640,
#  'parameters': 54390,
#  'usr': 54280,
#  'txt': 54110,
#  'properties': 54070,
#  'fields': 53910,
#  'creating': 53810,
#  'c++': 53710,
#  'note': 53450,
#  'look': 53410,
#  'entity': 53390,
#  'checkbox': 53360,
#  'bool': 53260,
#  'checked': 53070,
#  'did': 52890,
#  'columns': 52890,
#  'base': 52870,
#  'their': 52820,
#  'invoke': 52790,
#  'child': 52750,
#  'may': 52260,
#  'tab': 52260,
#  'drawable': 51970,
#  'say': 51880,
#  'cursor': 51840,
#  'configuration': 51710,
#  'listview': 51580,
#  'servlet': 51520,
#  'video': 51360,
#  'via': 50780,
#  'good': 50770,
#  'k': 50710,
#  'random': 50630,
#  'handle': 50620,
#  'eclipse': 50620,
#  'compile': 50570,
#  '06': 50520,
#  'thing': 50460,
#  'anything': 50440,
#  'nothing': 50410,
#  'nbsp': 50320,
#  'best': 50170,
#  'param': 50140,
#  'ok': 50010,
#  'localhost': 49830,
#  'shows': 49790,
#  'sender': 49690,
#  'framework': 49630,
#  '21': 49510,
#  'figure': 49340,
#  'socket': 49320,
#  'replace': 49210,
#  'match_parent': 49130,
#  'yes': 49050,
#  'section': 48820,
#  'phone': 48760,
#  '24': 48620,
#  'once': 48550,
#  'given': 48480,
#  'side': 48210,
#  'specific': 48190,
#  'player': 47960,
#  'ng': 47940,
#  'made': 47900,
#  'going': 47850,
#  'gets': 47850,
#  'missing': 47750,
#  'native': 47710,
#  'unknown': 47700,
#  'total': 47690,
#  'better': 47560,
#  'settings': 47410,
#  'security': 47390,
#  'err': 47250,
#  'take': 46950,
#  'vector': 46950,
#  'toast': 46900,
#  'linearlayout': 46660,
#  'single': 46630,
#  'level': 46510,
#  'settext': 46410,
#  'canvas': 46380,
#  'models': 46340,
#  'game': 46320,
#  'parameter': 46230,
#  'upload': 45950,
#  'too': 45950,
#  'give': 45940,
#  'those': 45860,
#  'fix': 45710,
#  'range': 45690,
#  'throws': 45680,
#  'functions': 45660,
#  'interface': 45640,
#  'fragment': 45610,
#  'reason': 45540,
#  're': 45410,
#  'most': 45340,
#  'endl': 45280,
#  'memory': 45230,
#  'hello': 45140,
#  'lines': 45010,
#  'active': 44970,
#  'around': 44930,
#  'ios': 44850,
#  'attribute': 44690,
#  'keep': 44630,
#  'had': 44590,
#  'max': 44470,
#  'spring': 44370,
#  'hide': 44340,
#  'bit': 44250,
#  'encoding': 44240,
#  'clear': 44060,
#  'reflect': 43780,
#  'hibernate': 43600,
#  'imageview': 43590,
#  'implement': 43450,
#  'getstring': 43380,
#  'statement': 43320,
#  'namespace': 43110,
#  'copy': 43090,
#  'word': 42990,
#  'math': 42740,
#  'ideas': 42740,
#  'adding': 42520,
#  '40': 42490,
#  'correctly': 42480,
#  'q': 42280,
#  'constructor': 41990,
#  'datetime': 41890,
#  'boost': 41860,
#  '200': 41840,
#  '2015': 41820,
#  'nil': 41790,
#  'move': 41670,
#  'place': 41550,
#  'similar': 41510,
#  'sample': 41500,
#  'times': 41360,
#  'nav': 41190,
#  'lot': 41090,
#  'price': 41040,
#  'match': 40860,
#  'actually': 40770,
#  'facebook': 40680,
#  'ready': 40550,
#  'undefined': 40480,
#  'red': 40370,
#  'bind': 40260,
#  'changes': 40250,
#  'stream': 40190,
#  'tools': 40120,
#  'defined': 40050,
#  'our': 40040,
#  'account': 40030,
#  '1000': 39850,
#  'params': 39660,
#  'h1': 39590,
#  'mail': 39570,
#  'push': 39550,
#  'tell': 39550,
#  'microsoft': 39540,
#  'mainactivity': 39420,
#  'bin': 39330,
#  'component': 39290,
#  'temp': 39260,
#  'expected': 39210,
#  'variables': 39030,
#  'visible': 39000,
#  'schemas': 38950,
#  'permission': 38950,
#  'three': 38930,
#  'maps': 38850,
#  'ex': 38790,
#  'switch': 38750,
#  'sort': 38710,
#  'split': 38680,
#  'func': 38680,
#  'ioexception': 38630,
#  'buffer': 38620,
#  '0px': 38610,
#  'admin': 38590,
#  'numbers': 38500,
#  'things': 38490,
#  'stop': 38350,
#  'entry': 38320,
#  'either': 38300,
#  '2016': 38140,
#  'packages': 38000,
#  'buttons': 37930,
#  'isn': 37850,
#  'chrome': 37840,
#  'nsstring': 37820,
#  'meta': 37780,
#  'loading': 37770,
#  'person': 37720,
#  'uri': 37610,
#  'resource': 37600,
#  'setting': 37540,
#  'binding': 37510,
#  'mode': 37490,
#  'off': 37480,
#  'release': 37460,
#  'details': 37410,
#  'equals': 37400,
#  'define': 37350,
#  'play': 37240,
#  'mobile': 37230,
#  'printstacktrace': 37150,
#  'panel': 37100,
#  '26': 37090,
#  'host': 37070,
#  'resources': 37070,
#  'setup': 37060,
#  'available': 37040,
#  'own': 37030,
#  'callback': 36880,
#  'cpp': 36870,
#  'token': 36820,
#  'port': 36790,
#  'contact': 36750,
#  'changed': 36720,
#  'solve': 36700,
#  '27': 36680,
#  'day': 36630,
#  'few': 36620,
#  'didn': 36570,
#  'im': 36340,
#  'full': 36340,
#  'msg': 36230,
#  'white': 36110,
#  'events': 36080,
#  'django': 36070,
#  'warning': 35990,
#  'scroll': 35980,
#  'maybe': 35980,
#  'bitmap': 35940,
#  '31': 35870,
#  'might': 35680,
#  'zygoteinit': 35680,
#  'render': 35660,
#  'pages': 35620,
#  'clicked': 35610,
#  'awt': 35530,
#  'todo': 35510,
#  'loaded': 35470,
#  'gives': 35400,
#  'views': 35360,
#  'require': 35360,
#  'stack': 35230,
#  'modal': 35210,
#  'pdf': 35190,
#  'dependency': 35000,
#  '32': 34960,
#  'names': 34750,
#  'conn': 34730,
#  'cache': 34660,
#  'camera': 34650,
#  'alt': 34630,
#  'groupid': 34580,
#  '2013': 34570,
#  'headers': 34560,
#  'comment': 34530,
#  'download': 34520,
#  'dll': 34520,
#  'bean': 34390,
#  'small': 34380,
#  'questions': 34340,
#  'calling': 34220,
#  'making': 34220,
#  'writing': 34170,
#  'join': 34160,
#  'artifactid': 34150,
#  'domain': 34070,
#  'calls': 33960,
#  'install': 33920,
#  'basically': 33880,
#  'fill': 33510,
#  'structure': 33510,
#  'h2': 33510,
#  'achieve': 33500,
#  'year': 33490,
#  'bootstrap': 33480,
#  'services': 33460,
#  'collection': 33430,
#  'amount': 33230,
#  'black': 33110,
#  'messages': 32990,
#  '60': 32980,
#  'jsfiddle': 32960,
#  'allow': 32950,
#  'language': 32900,
#  '_': 32870,
#  'record': 32840,
#  'animation': 32840,
#  'though': 32790,
#  'generate': 32720,
#  'seconds': 32710,
#  'rel': 32670,
#  'non': 32660,
#  'tableview': 32580,
#  'exit': 32570,
#  'media': 32550,
#  'unable': 32530,
#  'runtime': 32460,
#  'viewgroup': 32410,
#  'angular': 32320,
#  '2014': 32200,
#  'textbox': 32160,
#  'builder': 32070,
#  'successfully': 32070,
#  'written': 32040,
#  'draw': 31960,
#  'adapter': 31940,
#  'studio': 31900,
#  'swing': 31850,
#  'shown': 31830,
#  '500': 31810,
#  'started': 31740,
#  'links': 31740,
#  'invalid': 31680,
#  'layoutinflater': 31660,
#  'needs': 31610,
#  'maven': 31540,
#  'throw': 31490,
#  'factory': 31470,
#  'types': 31450,
#  'pattern': 31390,
#  'displayed': 31350,
#  'transform': 31130,
#  'radio': 31090,
#  'points': 31080,
#  'apk': 31080,
#  'space': 31070,
#  '28': 31030,
#  'bytes': 31020,
#  'exists': 30900,
#  'sub': 30860,
#  'until': 30840,
#  'edittext': 30810,
#  'valid': 30780,
#  'original': 30760,
#  '29': 30690,
#  'sdk': 30510,
#  'global': 30470,
#  '255': 30450,
#  'follows': 30340,
#  'never': 30260,
#  'solid': 30210,
#  'stored': 30200,
#  'isset': 29990,
#  'calendar': 29980,
#  'alloc': 29940,
#  'hover': 29810,
#  'reader': 29780,
#  'under': 29740,
#  'happens': 29720,
#  'stuff': 29670,
#  'properly': 29590,
#  'beans': 29530,
#  'en': 29460,
#  'csv': 29440,
#  'driver': 29410,
#  'month': 29390,
#  'previous': 29380,
#  '1px': 29350,
#  'struct': 29320,
#  'testing': 29310,
#  'h3': 29210,
#  'role': 29180,
#  'normal': 29180,
#  'children': 29170,
#  'kind': 29130,
#  'takes': 29100,
#  'except': 29100,
#  'whole': 29040,
#  'implementation': 28980,
#  'ie': 28950,
#  'tags': 28940,
#  'character': 28920,
#  'strong': 28920,
#  'simply': 28880,
#  'reading': 28830,
#  'contents': 28810,
#  'textarea': 28790,
#  'step': 28760,
#  'basic': 28750,
#  'installed': 28730,
#  'catalina': 28730,
#  'placeholder': 28650,
#  'implements': 28630,
#  'rest': 28620,
#  'updated': 28620,
#  'common': 28610,
#  'forms': 28550,
#  'returned': 28540,
#  'area': 28380,
#  'wondering': 28350,
#  'problems': 28340,
#  'ch': 28260,
#  ...}

# %%
for word in keys:
    if word not in top:
        del model._vocab[word]

# %%
# оставим только топ 10 000 слов
model.filter_vocab(n=10000)

# %%
# сделаем еще одну итерацию по датасету, уменьшив скорость обучения в 10 раз
acc = model.iterate_file(update_vocab=False, learning_rate=0.01)
print('%0.2f' % acc)
plt.plot(pd.Series(model._loss[:-25000]).rolling(10000).mean());
# Out:
# A Jupyter Widget
# 0.70

# %% [markdown]
# <font color="red">Вопрос 9.</font> К какому значению ближе всего полученное значение точности:
# <font color="red">Варианты ответа:</font>
# 1. 0.48
# 2. 0.58
# 3. 0.68
# 4. 0.78

# %% [markdown]
# ## 10. Прогнозирование тегов для новых вопросов
#
# В завершение этого задания вам предлагается реализовать метод `predict_proba`, который принимает строку, содержащую вопрос, а возвращает список предсказанных тегов вопроса с их вероятностями.

# %%
# Обновите определение класса LogRegressor
# Ваш код здесь

# %%
sentence = ("I want to improve my coding skills, so I have planned write " +
            "a Mobile Application.need to choose between Apple's iOS or Google's Android." +
            " my background: I have done basic programming in .Net,C/C++,Python and PHP " +
            "in college, so got OOP concepts covered. about my skill level, I just know " +
            "concepts and basic syntax. But can't write complex applications, if asked :(" +
            " So decided to hone my skills, And I wanted to know which is easier to " +
            "learn for a programming n00b. A) iOS which uses Objective C B) Android " + 
            "which uses Java. I want to decide based on difficulty " + 
            "level").lower().replace(',', '')
sentence = sentence.split(' ')
result = []
for tag in model._tags:
    zp=0
    for word in sentence:
        if word not in model._vocab:
            continue
        zp += model._w[tag][model._vocab[word]]
    p = sigmafunc(zp)
    print(tag)
    print('%0.2f' % p)
# Out:
# c++
# 0.00
# php
# 1.00
# java
# 0.00
# html
# 0.00
# c#
# 0.00
# jquery
# 0.00
# python
# 0.00
# android
# 0.53
# ios
# 1.00
# javascript
# 0.00

# %%
model._w['c++'][model._vocab['php']]
# Out:
# -15.453797949148674

# %%
p
# Out:
# 1.4387580530097372e-14

# %%
model = LogRegressor()
acc = model.iterate_file(update_vocab=True)
print('%0.2f' % acc)
model.filter_vocab(n=10000)
acc = model.iterate_file(update_vocab=False, learning_rate=0.01)
print('%0.2f' % acc)

# %%
sentence = ("I want to improve my coding skills, so I have planned write " +
            "a Mobile Application.need to choose between Apple's iOS or Google's Android." +
            " my background: I have done basic programming in .Net,C/C++,Python and PHP " +
            "in college, so got OOP concepts covered. about my skill level, I just know " +
            "concepts and basic syntax. But can't write complex applications, if asked :(" +
            " So decided to hone my skills, And I wanted to know which is easier to " +
            "learn for a programming n00b. A) iOS which uses Objective C B) Android " + 
            "which uses Java. I want to decide based on difficulty " + 
            "level").lower().replace(',', '')

# %%
sorted(model.predict_proba(sentence).items(), 
       key=lambda t: t[1], reverse=True)

# %% [markdown]
# <font color="red">Вопрос 10.</font> Отметьте все теги, ассоциирующиеся с данным вопросом, если порог принятия равен $0.9$. То есть считаем, что вопросу надо поставить некоторый тег, если вероятность его появления, предсказанная моделью, больше или равна 0.9.
#
# <font color="red">Варианты ответа:</font>
# 1. android
# 2. ios
# 3. php
# 4. java
